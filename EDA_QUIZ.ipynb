# %% [markdown]
# # QUIZ : EDA
# ---

# %% [markdown]
# ## 1. In a box plot, which of the following represents the interquartile range (IQR) ?
# 1. The entire length of the plot
# 2. The distance between the minimum and maximum values
# 3. The distance between the first and third quartiles
# 4. The length of the whiskers

# %% [markdown]
# The correct answer is:
#
# **3. The distance between the first and third quartiles**
#
# ### Explanation:
#
# * The **interquartile range (IQR)** is the range between the **first quartile (Q1)** and the **third quartile (Q3)**:
#
#   $$
#   \text{IQR} = Q3 - Q1
#   $$
#
# * In a **box plot**, this is represented by the **length of the box** (not the whiskers).
#
# * The **whiskers** extend to the minimum and maximum values **within** 1.5 × IQR from the quartiles, but they are **not** part of the IQR.
#
# ✅ **Correct: Option 3**
# ❌ Option 1: This includes whiskers, which are not part of the IQR
# ❌ Option 2: That’s the total range, not the IQR
# ❌ Option 4: Whiskers go beyond Q1 and Q3, not part of IQR

# %% [markdown]
# ## 2. In which scenario would you prefer a bar chart over a pie chart?
# 1. When you want to compare the proportions of a whole
# 2. When you have a large number of categories
# 3. When you want to visualize the distribution of a continuous variable
# 4. When you want to highlight trends over time

# %% [markdown]
# The correct answer is:
#
# **2. When you have a large number of categories**
#
# ### Explanation:
#
# * **Bar Chart** is better than a **Pie Chart** when:
#
#   * You have **many categories**, because bar charts remain readable, while pie charts become cluttered.
#   * You need to **compare values precisely** — it's easier to compare bar lengths than pie slice angles.
#
# Let’s review each option:
#
# 1. **When you want to compare the proportions of a whole**
#    🔸 Best for **pie charts**, not bar charts
#    ❌ **Incorrect**
#
# 2. **When you have a large number of categories**
#    ✅ **Best for bar charts** — more readable than pie charts
#    ✅ **Correct Answer**
#
# 3. **When you want to visualize the distribution of a continuous variable**
#    🔸 Use a **histogram** or **box plot**, not a bar or pie chart
#    ❌ **Incorrect**
#
# 4. **When you want to highlight trends over time**
#    🔸 Use a **line chart**, not a bar or pie chart
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2**

# %% [markdown]
# ## 3. Which plot is best for comparing the distribution of data across different categories?
# 1. Violin Plot
# 2. Box Plot
# 3. Histogram
# 4. Heatmap

# %% [markdown]
# The correct answer is:
#
# **2. Box Plot**
#
# ### Explanation:
#
# A **box plot** is ideal for comparing the **distribution of data across different categories** because it:
#
# * Shows the **median**, **quartiles (Q1 & Q3)**, and **outliers** for each category.
# * Allows **side-by-side comparison** of distributions across multiple groups.
# * Is especially useful when comparing **spread, central tendency**, and **skewness** between categories.
#
# ---
#
# Let's analyze all options:
#
# 1. **Violin Plot**
#
#    * Shows distribution and density more precisely than a box plot
#    * Good for detailed comparison, but **more complex to interpret**
#    * ✅ Also a good choice, but **not as standard or simple** as box plots
#      🔸 **Acceptable**, but not best for basic comparison
#
# 2. **Box Plot**
#
#    * ✅ Widely used and easy to interpret
#    * ✅ Best for comparing multiple distributions clearly
#      ✅ **Correct Answer**
#
# 3. **Histogram**
#
#    * Good for showing the distribution of a **single continuous variable**
#    * ❌ Not ideal for comparing multiple categories
#      ❌ **Incorrect**
#
# 4. **Heatmap**
#
#    * Best for showing **intensity or frequency** across two dimensions
#    * ❌ Not designed for detailed distribution comparison
#      ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – Box Plot**

# %% [markdown]
# ## 4. What is a major drawback of 3D plots?
# 1. They are difficult to create
# 2. They are difficult to interpret
# 3. They are not visually appealing
# 4. They can only display two variables

# %% [markdown]
# The correct answer is:
#
# **2. They are difficult to interpret**
#
# ---
#
# ### Explanation:
#
# **3D plots** may look visually impressive, but they often have the **major drawback** of being **hard to read and interpret**, especially when:
#
# * Data points overlap due to perspective
# * Axes become unclear
# * View angles distort perception
# * It becomes difficult to compare values accurately
#
# ---
#
# Let’s break down the options:
#
# 1. **They are difficult to create**
#    ❌ Not true — modern tools (like matplotlib, Plotly) make 3D plots fairly easy to create
#    ❌ **Incorrect**
#
# 2. **They are difficult to interpret**
#    ✅ Yes — perspective and depth can obscure data relationships and confuse viewers
#    ✅ **Correct Answer**
#
# 3. **They are not visually appealing**
#    ❌ Actually, 3D plots can be very attractive visually
#    ❌ **Incorrect**
#
# 4. **They can only display two variables**
#    ❌ Wrong — 3D plots are used specifically to display **three variables**
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – They are difficult to interpret**

# %% [markdown]
# ## 5. What does the width of the 'violin' in a violin plot represent?
# 1. The range of the data
# 2. The density of the data at different values
# 3. The mean of the data
# 4. The number of observations

# %% [markdown]
# The correct answer is:
#
# **2. The density of the data at different values**
#
# ---
#
# ### Explanation:
#
# In a **violin plot**, the **width of the 'violin'** at any given point represents the **probability density** (or **data concentration**) at that value. In other words:
#
# * **Wider sections** of the violin indicate **more data points** (higher density).
# * **Narrow sections** indicate **fewer data points** (lower density).
# * It's essentially a **smoothed histogram mirrored on both sides**, often combined with a **box plot** inside.
#
# ---
#
# Let’s evaluate the options:
#
# 1. **The range of the data**
#    ❌ That's represented by the length, not the width
#    ❌ **Incorrect**
#
# 2. **The density of the data at different values**
#    ✅ Width = how densely data is distributed at a specific value
#    ✅ **Correct Answer**
#
# 3. **The mean of the data**
#    ❌ The mean may be shown as a point, but it's not represented by the width
#    ❌ **Incorrect**
#
# 4. **The number of observations**
#    ❌ Overall number affects density, but **width at a specific point** = local density, not count
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – The density of the data at different values**

# %% [markdown]
# ## 6. A heatmap is particularly useful for
# 1. Displaying the frequency distribution of a single variable
# 2. Showing the correlation between multiple variables
# 3. Illustrating the median of a dataset
# 4. Plotting time series data

# %% [markdown]
# The correct answer is:
#
# **2. Showing the correlation between multiple variables**
#
# ---
#
# ### Explanation:
#
# A **heatmap** is particularly useful for:
#
# * **Visualizing correlations** in a **correlation matrix**, where color intensity indicates the strength and direction of relationships.
# * Identifying patterns, clusters, or anomalies across two dimensions.
#
# ---
#
# Let’s evaluate each option:
#
# 1. **Displaying the frequency distribution of a single variable**
#    ❌ Use a **histogram** for this, not a heatmap
#    ❌ **Incorrect**
#
# 2. **Showing the correlation between multiple variables**
#    ✅ Heatmaps are often used to display **correlation matrices** in data analysis
#    ✅ **Correct Answer**
#
# 3. **Illustrating the median of a dataset**
#    ❌ Medians are better shown in **box plots**
#    ❌ **Incorrect**
#
# 4. **Plotting time series data**
#    ❌ Use **line plots** or **area charts** for time series
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – Showing the correlation between multiple variables**

# %% [markdown]
# ## 7. Which type of plot is most appropriate for displaying the distribution of a categorical variable?
# 1. Histogram
# 2. Bar Chart
# 3. Scatter Plot
# 4. Line Chart

# %% [markdown]
# The correct answer is:
#
# **2. Bar Chart**
#
# ---
#
# ### Explanation:
#
# A **bar chart** is the most appropriate plot for displaying the **distribution of a categorical variable** because:
#
# * It shows the **frequency** or **count** of each category.
# * Each bar represents a **distinct category**, making it ideal for comparing **categorical data**.
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Histogram**
#    ❌ Used for **continuous** (numeric) variables, not categorical
#    ❌ **Incorrect**
#
# 2. **Bar Chart**
#    ✅ Best for showing how often each **category** occurs
#    ✅ **Correct Answer**
#
# 3. **Scatter Plot**
#    ❌ Used for visualizing relationships between **two numeric variables**
#    ❌ **Incorrect**
#
# 4. **Line Chart**
#    ❌ Used for **time series** or ordered data
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – Bar Chart**

# %% [markdown]
# ## 8. Multivariate Analysis is particularly useful for which of the following?
# 1. Predicting categorical outcomes with one variable
# 2. Analyzing relationship between two categorical variables
# 3. Understanding complex relationships involving multiple variables
# 4. Analyzing time series data

# %% [markdown]
# The correct answer is:
#
# **3. Understanding complex relationships involving multiple variables**
#
# ---
#
# ### Explanation:
#
# **Multivariate Analysis** refers to statistical techniques used to analyze data that involves **more than two variables** at the same time. It's particularly useful for:
#
# * **Identifying patterns** and **interactions** among multiple variables
# * **Predictive modeling** (e.g., multiple regression, logistic regression)
# * **Dimensionality reduction** (e.g., PCA)
# * **Clustering and classification** problems
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Predicting categorical outcomes with one variable**
#    ❌ That's **univariate analysis** or **simple classification**
#    ❌ **Incorrect**
#
# 2. **Analyzing relationship between two categorical variables**
#    ❌ That's **bivariate analysis** (e.g., Chi-square test)
#    ❌ **Incorrect**
#
# 3. **Understanding complex relationships involving multiple variables**
#    ✅ This is the **core purpose** of multivariate analysis
#    ✅ **Correct Answer**
#
# 4. **Analyzing time series data**
#    ❌ Time series analysis is a **different branch** (though can be multivariate too)
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 3 – Understanding complex relationships involving multiple variables**

# %% [markdown]
# ## 9. What is the primary use of scatter plots in Bivariate Analysis?
# 1. To display the distribution of a single variable
# 2. To visualize the relationship between two variables
# 3. To compare the means of two variables
# 4. To test for statistical significance

# %% [markdown]
# The correct answer is:
#
# **2. To visualize the relationship between two variables**
#
# ---
#
# ### Explanation:
#
# In **bivariate analysis**, a **scatter plot** is primarily used to:
#
# * **Visualize the relationship** or **association** between two **numerical variables**
# * Identify **patterns**, such as:
#
#   * Positive or negative correlation
#   * Linear or nonlinear trends
#   * Presence of outliers
#
# ---
#
# Let’s review each option:
#
# 1. **To display the distribution of a single variable**
#    ❌ That’s done using **histograms** or **box plots**
#    ❌ **Incorrect**
#
# 2. **To visualize the relationship between two variables**
#    ✅ Scatter plots are perfect for this in bivariate analysis
#    ✅ **Correct Answer**
#
# 3. **To compare the means of two variables**
#    ❌ Use **bar plots**, **t-tests**, or **box plots** for comparing means
#    ❌ **Incorrect**
#
# 4. **To test for statistical significance**
#    ❌ Use statistical tests (e.g., t-test, ANOVA, chi-square) for that, not a plot
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – To visualize the relationship between two variables**

# %% [markdown]
# ## 10. Which type of plot shows the relationship between every pair of variables in a dataset?
# 1. Heatmap
# 2. Pair Plot
# 3. Violin Plot
# 4. Box Plot

# %% [markdown]
# The correct answer is:
#
# **2. Pair Plot**
#
# ---
#
# ### Explanation:
#
# A **pair plot** (also known as a **scatterplot matrix**) is used to:
#
# * Show the **relationship between every pair of numerical variables** in a dataset
# * Display:
#
#   * **Scatter plots** for each pair of variables
#   * **Histograms** or **kernel density plots** on the diagonals (for individual variable distributions)
#
# This makes it ideal for **exploratory data analysis (EDA)** to detect correlations, patterns, and outliers.
#
# ---
#
# Let’s review each option:
#
# 1. **Heatmap**
#    🔸 Can show correlation between variables, but **not actual scatter plots**
#    ❌ **Incorrect**
#
# 2. **Pair Plot**
#    ✅ Shows a grid of scatter plots for **all variable pairs**
#    ✅ **Correct Answer**
#
# 3. **Violin Plot**
#    ❌ Used to show distribution of a **single variable across categories**
#    ❌ **Incorrect**
#
# 4. **Box Plot**
#    ❌ Good for comparing **distributions** across categories, but not for **variable-to-variable relationships**
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – Pair Plot**

# %% [markdown]
# ## 11. Which plot is best suited for analyzing the relationship between three continuous variables?
# 1. Histogram
# 2. 3D Scatter Plot
# 3. Box Plot
# 4. Bar Chart

# %% [markdown]
# The correct answer is:
#
# **2. 3D Scatter Plot**
#
# ---
#
# ### Explanation:
#
# A **3D scatter plot** is best suited for analyzing the relationship between **three continuous variables**, because it:
#
# * Plots data points in **three-dimensional space** using:
#
#   * X-axis → 1st variable
#   * Y-axis → 2nd variable
#   * Z-axis → 3rd variable
# * Helps visualize how the three variables interact and identify patterns or clusters.
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Histogram**
#    ❌ Used for distribution of **one continuous variable**
#    ❌ **Incorrect**
#
# 2. **3D Scatter Plot**
#    ✅ Designed to visualize **relationships among three numeric variables**
#    ✅ **Correct Answer**
#
# 3. **Box Plot**
#    ❌ Best for showing **distribution and outliers** for a **single variable** (can compare across categories)
#    ❌ **Incorrect**
#
# 4. **Bar Chart**
#    ❌ Used for **categorical** data, not continuous variables
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – 3D Scatter Plot**

# %% [markdown]
# ## 12. In Multivariate Analysis, Which technique is used to reduce the dimensionality of the data?
# 1. Principal Component Analysis (PCA)
# 2. Linear Regression
# 3. Correlation
# 4. T-test

# %% [markdown]
# The correct answer is:
#
# **1. Principal Component Analysis (PCA)**
#
# ---
#
# ### Explanation:
#
# **Principal Component Analysis (PCA)** is a statistical technique used in **multivariate analysis** to:
#
# * **Reduce the dimensionality** of large datasets
# * Transform the data into a **new set of variables (principal components)** that retain most of the original variability
# * Simplify the dataset while preserving patterns and relationships
#
# This is especially useful when:
#
# * You have **many variables** that are **correlated**
# * You want to **visualize** high-dimensional data
# * You aim to **improve performance** in machine learning models by reducing features
#
# ---
#
# Let’s review the other options:
#
# 2. **Linear Regression**
#    ❌ Used for **predictive modeling**, not for dimensionality reduction
#    ❌ **Incorrect**
#
# 3. **Correlation**
#    ❌ Measures the **strength of relationship** between two variables, not used for reducing dimensions
#    ❌ **Incorrect**
#
# 4. **T-test**
#    ❌ Used to **compare means** between groups, not to reduce dimensionality
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 1 – Principal Component Analysis (PCA)**

# %% [markdown]
# ## 13. What is the range of the correlation coefficient?
# 1. 0 to 1
# 2. -1 to 0
# 3. -1 to 1
# 4. 1 to 2

# %% [markdown]
# The correct answer is:
#
# **3. -1 to 1**
#
# ---
#
# ### Explanation:
#
# The **correlation coefficient** (typically **Pearson’s r**) measures the **strength and direction of the linear relationship** between two variables.
#
# * **+1** → Perfect positive linear correlation
# * **0** → No linear correlation
# * **-1** → Perfect negative linear correlation
#
# ---
#
# Let’s evaluate the options:
#
# 1. **0 to 1**
#    ❌ Only includes positive correlation
#    ❌ **Incorrect**
#
# 2. **-1 to 0**
#    ❌ Only includes negative correlation
#    ❌ **Incorrect**
#
# 3. **-1 to 1**
#    ✅ Includes the full range of possible linear correlations
#    ✅ **Correct Answer**
#
# 4. **1 to 2**
#    ❌ Correlation cannot exceed 1
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 3 – -1 to 1**

# %% [markdown]
# ## 14. Which of the following methods is commonly used in Bivariate Analysis?
# 1. Histogram
# 2. Bar Chart
# 3. Correlation
# 4. Violin PLot

# %% [markdown]
# The correct answer is:
#
# **3. Correlation**
#
# ---
#
# ### Explanation:
#
# In **bivariate analysis**, the goal is to examine the **relationship between two variables**. One of the most **common methods** for this is:
#
# ### ✅ **Correlation**
#
# * Measures the **strength and direction** of a **linear relationship** between two numerical variables.
# * Common types: **Pearson correlation**, **Spearman rank correlation**
# * Output: A value between **-1 and 1**
#
# ---
#
# Let’s evaluate the other options:
#
# 1. **Histogram**
#    ❌ Used for **univariate analysis** — showing the distribution of **one variable**
#    ❌ **Incorrect**
#
# 2. **Bar Chart**
#    ❌ Best for categorical data; not typically used to analyze relationships between two variables
#    ❌ **Incorrect**
#
# 3. **Correlation**
#    ✅ Core technique in **bivariate analysis**
#    ✅ **Correct Answer**
#
# 4. **Violin Plot**
#    🔸 More often used to **show distribution** of a variable across categories
#    ❌ Not a primary method in bivariate analysis
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 3 – Correlation**

# %% [markdown]
# ## 15. What does Bivariate Analysis primarily examine?
# 1. Relationships between twp variables
# 2. Relationships between three variables
# 3. Relationships within a single variable
# 4. None of the above

# %% [markdown]
# The correct answer is:
#
# **1. Relationships between two variables**
#
# ---
#
# ### Explanation:
#
# **Bivariate Analysis** is a statistical method that focuses on:
#
# * **Examining the relationship**, association, or correlation between **two variables**
# * It can involve:
#
#   * **Numerical vs. numerical** (e.g., correlation, scatter plots)
#   * **Categorical vs. numerical** (e.g., box plots, t-tests)
#   * **Categorical vs. categorical** (e.g., cross-tabulation, chi-square test)
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Relationships between two variables**
#    ✅ This is the **definition** of bivariate analysis
#    ✅ **Correct Answer**
#
# 2. **Relationships between three variables**
#    ❌ That’s **multivariate analysis**
#    ❌ **Incorrect**
#
# 3. **Relationships within a single variable**
#    ❌ That’s **univariate analysis**
#    ❌ **Incorrect**
#
# 4. **None of the above**
#    ❌ The correct definition is listed in option 1
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 1 – Relationships between two variables**

# %% [markdown]
# ## 16. What is the primary purpose of Exploratory Data Analysis (EDA) ?
# 1. To create complex models
# 2. To summarize the main characteristics of the data
# 3. To clean the data
# 4. To perform hypothesis testing

# %% [markdown]
# The correct answer is:
#
# **2. To summarize the main characteristics of the data**
#
# ---
#
# ### Explanation:
#
# **Exploratory Data Analysis (EDA)** is the **first step** in the data analysis process, and its **primary purpose** is to:
#
# * **Understand** the structure, patterns, trends, and anomalies in the data
# * **Summarize** the main features using **visualizations** (like histograms, box plots, scatter plots) and **descriptive statistics** (mean, median, mode, standard deviation)
# * Help formulate hypotheses or choose appropriate modeling techniques later
#
# ---
#
# Let’s evaluate the options:
#
# 1. **To create complex models**
#    ❌ Model building comes **after** EDA
#    ❌ **Incorrect**
#
# 2. **To summarize the main characteristics of the data**
#    ✅ This is the **core goal** of EDA
#    ✅ **Correct Answer**
#
# 3. **To clean the data**
#    🔸 Cleaning is part of data preprocessing, often done **before or alongside** EDA
#    ❌ **Incorrect as the primary purpose**
#
# 4. **To perform hypothesis testing**
#    ❌ Hypothesis testing is part of **confirmatory** data analysis, not exploratory
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – To summarize the main characteristics of the data**

# %% [markdown]
# ## 17. Which of the following plots is best for identifying the distribution of a continuous variable?
# 1. Bar Chart
# 2. Histogram
# 3. Pie Chart
# 4. Line Chart

# %% [markdown]
# The correct answer is:
#
# **2. Histogram**
#
# ---
#
# ### Explanation:
#
# A **histogram** is specifically designed to:
#
# * **Visualize the distribution** of a **continuous variable**
# * Show how the data is **spread** across different **intervals (bins)**
# * Help identify:
#
#   * **Skewness**
#   * **Modality** (e.g., unimodal, bimodal)
#   * **Outliers**
#   * **Range and spread**
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Bar Chart**
#    ❌ Best for **categorical variables**, not continuous
#    ❌ **Incorrect**
#
# 2. **Histogram**
#    ✅ Ideal for continuous data distribution
#    ✅ **Correct Answer**
#
# 3. **Pie Chart**
#    ❌ Used to show **proportions** in categorical data
#    ❌ **Incorrect**
#
# 4. **Line Chart**
#    ❌ Best for **time series** or continuous trends over an ordered sequence
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – Histogram**

# %% [markdown]
# ## 18. Which statistical measure is used to represent the central tendency of a data set?
# 1. Standard deviation
# 2. Variance
# 3. Mean
# 4. Range

# %% [markdown]
# The correct answer is:
#
# **3. Mean**
#
# ---
#
# ### Explanation:
#
# The **mean** (also called the **average**) is one of the most commonly used **measures of central tendency**, representing the **central or typical value** in a dataset.
#
# Other measures of central tendency include:
#
# * **Median** – the middle value when data is sorted
# * **Mode** – the most frequent value
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Standard deviation**
#    ❌ Measures **spread/dispersion**, not central tendency
#    ❌ **Incorrect**
#
# 2. **Variance**
#    ❌ Also measures **how much data varies** from the mean
#    ❌ **Incorrect**
#
# 3. **Mean**
#    ✅ Represents the **center** of the data
#    ✅ **Correct Answer**
#
# 4. **Range**
#    ❌ Describes the **spread** (max - min), not the center
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 3 – Mean**

# %% [markdown]
# ## 19. Which of the following is NOT a technique used in Univariate Analysis?
# 1. Histogram
# 2. Bar Chart
# 3. Scatter Plot
# 4. Box Plot

# %% [markdown]
# The correct answer is:
#
# **3. Scatter Plot**
#
# ---
#
# ### Explanation:
#
# **Univariate analysis** involves analyzing **a single variable** to understand its distribution, central tendency, and spread. Common techniques include:
#
# * **Histogram** – for continuous data
# * **Bar Chart** – for categorical data
# * **Box Plot** – for detecting outliers and spread in a single variable
#
# ---
#
# Let’s evaluate each option:
#
# 1. **Histogram**
#    ✅ Used in univariate analysis for **continuous variables**
#    ✅ **Correct technique**
#
# 2. **Bar Chart**
#    ✅ Used in univariate analysis for **categorical variables**
#    ✅ **Correct technique**
#
# 3. **Scatter Plot**
#    ❌ Requires **two variables** (x and y axes)
#    ❌ Used in **bivariate analysis**, **not univariate**
#    ❌ **Correct Answer**
#
# 4. **Box Plot**
#    ✅ Used to summarize **one variable** (median, quartiles, outliers)
#    ✅ **Correct technique**
#
# ✅ **Correct: Option 3 – Scatter Plot**

# %% [markdown]
# ## 20. What is Univariate Analysis?
# 1. Analysis of two variables
# 2. Analysis of three or more variables
# 3. Analysis of a single variable
# 4. None of the above

# %% [markdown]
# The correct answer is:
#
# **3. Analysis of a single variable**
#
# ---
#
# ### Explanation:
#
# **Univariate Analysis** is the **simplest form of data analysis**, focusing on:
#
# * **One variable at a time**
# * Describing its **distribution**, **central tendency** (mean, median, mode), and **spread** (range, variance, standard deviation)
# * Common plots: **histogram**, **bar chart**, **box plot**, **pie chart** (for categorical data)
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Analysis of two variables**
#    ❌ That’s **bivariate analysis**
#    ❌ **Incorrect**
#
# 2. **Analysis of three or more variables**
#    ❌ That’s **multivariate analysis**
#    ❌ **Incorrect**
#
# 3. **Analysis of a single variable**
#    ✅ This is the definition of **univariate analysis**
#    ✅ **Correct Answer**
#
# 4. **None of the above**
#    ❌ Incorrect — option 3 is correct
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 3 – Analysis of a single variable**

# %% [markdown]
# ## 21. Why is EDA important before building predictive models?
# 1. It improves the speed of the model
# 2. It helps to understand the data structure and identify potential issues
# 3. It reduces the size of the data
# 4. It ensures that models will be accurate

# %% [markdown]
# The correct answer is:
#
# **2. It helps to understand the data structure and identify potential issues**
#
# ---
#
# ### Explanation:
#
# **Exploratory Data Analysis (EDA)** is a crucial step before building predictive models because it:
#
# * Reveals the **structure** and **distribution** of the data
# * Identifies **missing values**, **outliers**, **inconsistencies**, and **data quality issues**
# * Helps in choosing appropriate **features**, **transformations**, and **modeling techniques**
#
# ---
#
# Let’s evaluate each option:
#
# 1. **It improves the speed of the model**
#    ❌ EDA doesn’t directly affect model speed; that’s more related to algorithms and hardware
#    ❌ **Incorrect**
#
# 2. **It helps to understand the data structure and identify potential issues**
#    ✅ This is the **main purpose** of EDA
#    ✅ **Correct Answer**
#
# 3. **It reduces the size of the data**
#    ❌ EDA may lead to feature reduction, but size reduction is **not its primary goal**
#    ❌ **Incorrect**
#
# 4. **It ensures that models will be accurate**
#    ❌ EDA helps improve data quality, but **accuracy is not guaranteed**
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – It helps to understand the data structure and identify potential issues**

# %% [markdown]
# ## 22. EDA is crucial for identifying which of the following in a dataset?
# 1. The target variable
# 2. Patterns and relationships
# 3. Final predictions
# 4. Training time of models

# %% [markdown]
# The correct answer is:
#
# **2. Patterns and relationships**
#
# ---
#
# ### Explanation:
#
# **Exploratory Data Analysis (EDA)** is essential for:
#
# * Discovering **patterns**, **trends**, and **relationships** between variables
# * Understanding data distribution, variable types, and potential **correlations**
# * Detecting **anomalies**, **missing values**, and **outliers**
#
# This helps in making informed decisions for **feature selection**, **data cleaning**, and **modeling strategy**.
#
# ---
#
# Let’s review each option:
#
# 1. **The target variable**
#    ❌ The target variable is usually predefined or chosen based on the problem statement, not discovered via EDA
#    ❌ **Incorrect**
#
# 2. **Patterns and relationships**
#    ✅ A core objective of EDA
#    ✅ **Correct Answer**
#
# 3. **Final predictions**
#    ❌ Predictions come **after modeling**, not during EDA
#    ❌ **Incorrect**
#
# 4. **Training time of models**
#    ❌ Model training time depends on algorithms and data size, not EDA
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – Patterns and relationships**

# %% [markdown]
# ## 23. Which of the following is NOT a common tool used in EDA?
# 1. Histograms
# 2. Box Plots
# 3. Confusion matrix
# 4. Scatter Plots

# %% [markdown]
# The correct answer is:
#
# **3. Confusion matrix**
#
# ---
#
# ### Explanation:
#
# The **confusion matrix** is a tool used to **evaluate classification models**, not for **Exploratory Data Analysis (EDA)**. It helps assess model performance by showing:
#
# * True Positives (TP)
# * False Positives (FP)
# * True Negatives (TN)
# * False Negatives (FN)
#
# ---
#
# Let’s review the options:
#
# 1. **Histograms**
#    ✅ Used in EDA to show **distribution of continuous variables**
#    ✅ **Common EDA tool**
#
# 2. **Box Plots**
#    ✅ Used to visualize **spread, central tendency, and outliers**
#    ✅ **Common EDA tool**
#
# 3. **Confusion matrix**
#    ❌ Used for **model evaluation**, not data exploration
#    ❌ **Correct Answer**
#
# 4. **Scatter Plots**
#    ✅ Used in EDA to explore **relationships between two numeric variables**
#    ✅ **Common EDA tool**
#
# ✅ **Correct: Option 3 – Confusion matrix**

# %% [markdown]
# ## 24. What is the amin advantage of using graphical representations in EDA?
# 1. they provide precise numerical values
# 2. They simplify complex data and highlights patterns
# 3. They perform calculations automatically
# 4. They eliminate the need for statistical analysis

# %% [markdown]
# The correct answer is:
#
# **2. They simplify complex data and highlight patterns**
#
# ---
#
# ### Explanation:
#
# The **main advantage** of using **graphical representations** (like histograms, scatter plots, box plots) in **Exploratory Data Analysis (EDA)** is that they:
#
# * **Make complex data easier to understand**
# * **Reveal patterns**, **trends**, **outliers**, and **relationships** that may not be obvious in raw numbers
# * Support intuitive and quick insights before any formal modeling
#
# ---
#
# Let’s evaluate the options:
#
# 1. **They provide precise numerical values**
#    ❌ Graphs show **visual trends**, not precise figures — for that, use tables/statistics
#    ❌ **Incorrect**
#
# 2. **They simplify complex data and highlight patterns**
#    ✅ This is the primary purpose of visualization in EDA
#    ✅ **Correct Answer**
#
# 3. **They perform calculations automatically**
#    ❌ Graphs display results, but **don’t do the math** — tools/software perform calculations
#    ❌ **Incorrect**
#
# 4. **They eliminate the need for statistical analysis**
#    ❌ Visuals **complement**, not replace, statistical analysis
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – They simplify complex data and highlight patterns**

# %% [markdown]
# ## 25. Which plot would you use to detect outliers in a continuous variable?
# 1. Box Plot
# 2. Bar Chart
# 3. Line Chart
# 4. Histogram

# %% [markdown]
# The correct answer is:
#
# **1. Box Plot**
#
# ---
#
# ### Explanation:
#
# A **box plot** (also called a **box-and-whisker plot**) is specifically designed to:
#
# * Display the **distribution** of a continuous variable
# * Show the **median**, **quartiles (Q1 and Q3)**, and **interquartile range (IQR)**
# * Clearly identify **outliers** as data points that lie beyond **1.5 × IQR** from the quartiles
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Box Plot**
#    ✅ Best for **detecting outliers** in a continuous variable
#    ✅ **Correct Answer**
#
# 2. **Bar Chart**
#    ❌ Used for **categorical variables**, not suitable for outlier detection
#    ❌ **Incorrect**
#
# 3. **Line Chart**
#    ❌ Useful for **time series trends**, not for detecting outliers in distributions
#    ❌ **Incorrect**
#
# 4. **Histogram**
#    🔸 Can show unusual values but **not as clearly** or systematically as a box plot
#    ❌ **Not the best tool for detecting outliers**
#
# ✅ **Correct: Option 1 – Box Plot**

# %% [markdown]
# ## 26. Which graphical method combines features of a box plot and a kernel density plot?
# 1. Violin Plot
# 2. Scatter Plot
# 3. Line Chart
# 4. Heatmap

# %% [markdown]
# The correct answer is:
#
# **1. Violin Plot**
#
# ---
#
# ### Explanation:
#
# A **violin plot** combines the features of:
#
# * A **box plot**: showing the median, quartiles, and possible outliers
# * A **kernel density plot**: displaying the **probability density** of the data at different values (represented by the width of the violin)
#
# This makes it useful for visualizing the **distribution and spread** of a continuous variable, especially when comparing across **multiple categories**.
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Violin Plot**
#    ✅ Merges **box plot** and **density plot** features
#    ✅ **Correct Answer**
#
# 2. **Scatter Plot**
#    ❌ Shows relationships between two numeric variables
#    ❌ **Incorrect**
#
# 3. **Line Chart**
#    ❌ Best for showing trends over time, not distribution or density
#    ❌ **Incorrect**
#
# 4. **Heatmap**
#    ❌ Used to show intensity/patterns across two variables, often with color
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 1 – Violin Plot**

# %% [markdown]
# ## 27. Which type pf lot is best for visualizing the change in a variable over time?
# 1. Scatter Plot
# 2. Box Plot
# 3. Line Chart
# 4. Bar Chart

# %% [markdown]
# The correct answer is:
#
# **3. Line Chart**
#
# ---
#
# ### Explanation:
#
# A **line chart** is the best choice for visualizing how a variable **changes over time** because it:
#
# * Connects data points in **chronological order**
# * Clearly shows **trends**, **patterns**, **increases**, or **decreases**
# * Is ideal for **time series data**
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Scatter Plot**
#    ❌ Shows relationships between two variables, but not ideal for continuous time tracking
#    ❌ **Incorrect**
#
# 2. **Box Plot**
#    ❌ Summarizes distribution (median, IQR), not changes over time
#    ❌ **Incorrect**
#
# 3. **Line Chart**
#    ✅ Designed to track **changes over time**
#    ✅ **Correct Answer**
#
# 4. **Bar Chart**
#    🔸 Can show time-based data but is **less effective** for continuous trends
#    ❌ **Not the best choice**
#
# ✅ **Correct: Option 3 – Line Chart**

# %% [markdown]
# ## 28. IN a scatter plot, what does each point represent ?
# 1. A single variable
# 2. A pair of variables
# 3. A statistical summary
# 4. A categorical frequency

# %% [markdown]
# The correct answer is:
#
# **2. A pair of variables**
#
# ---
#
# ### Explanation:
#
# In a **scatter plot**, each point represents a **single observation** consisting of a **pair of values** from two variables:
#
# * The **x-coordinate** comes from one variable
# * The **y-coordinate** comes from another variable
#
# This makes scatter plots ideal for:
#
# * **Visualizing relationships** between two **numerical variables**
# * Detecting **correlations**, **clusters**, and **outliers**
#
# ---
#
# Let’s evaluate the options:
#
# 1. **A single variable**
#    ❌ That’s true for histograms or box plots, not scatter plots
#    ❌ **Incorrect**
#
# 2. **A pair of variables**
#    ✅ Each point = one observation with values for two variables
#    ✅ **Correct Answer**
#
# 3. **A statistical summary**
#    ❌ Scatter plots show raw data points, not summaries
#    ❌ **Incorrect**
#
# 4. **A categorical frequency**
#    ❌ That would be represented by a **bar chart or pie chart**
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – A pair of variables**

# %% [markdown]
# ## 29. A heatmap is particulary useful for:
# 1. Displaying the frequency distribution of a single variable
# 2. Showing the correlation between multiple variables
# 3. Illustrating the median of a dateset
# 4. Plotting time series data

# %% [markdown]
# The correct answer is:
#
# **2. Showing the correlation between multiple variables**
#
# ---
#
# ### Explanation:
#
# A **heatmap** is particularly useful for visualizing a **correlation matrix**, where:
#
# * Each cell shows the **correlation coefficient** between a pair of variables
# * **Color intensity** represents the **strength and direction** of the correlation
# * It helps quickly identify **strong positive/negative relationships**, **multicollinearity**, or **variable clusters**
#
# ---
#
# Let’s evaluate the options:
#
# 1. **Displaying the frequency distribution of a single variable**
#    ❌ Use a **histogram** or **bar chart** for this
#    ❌ **Incorrect**
#
# 2. **Showing the correlation between multiple variables**
#    ✅ Ideal use of heatmaps, especially in data exploration
#    ✅ **Correct Answer**
#
# 3. **Illustrating the median of a dataset**
#    ❌ Use **box plots** or **summary statistics**, not heatmaps
#    ❌ **Incorrect**
#
# 4. **Plotting time series data**
#    ❌ Use **line charts** or **area charts** for time series
#    ❌ **Incorrect**
#
# ✅ **Correct: Option 2 – Showing the correlation between multiple variables**
